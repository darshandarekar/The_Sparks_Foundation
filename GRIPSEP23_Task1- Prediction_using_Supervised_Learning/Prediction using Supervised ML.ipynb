# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>Read & Import packages.</strong></font></p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>Reading Dataset.</strong></font></p>

# %%
df=pd.read_csv('student_scores.csv')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %% [markdown]
# <p><font size = 3, color ="blue">Dataset contains total of 25 records.</font></p>

# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>Descriptive Statistics.</strong></font></p>

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>Exploratory Data Analysis.</strong></font></p>

# %% [markdown]
# ### Checking NaN and Duplicated Values

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - Dataset does not contain any NaN and Duplicated Values

# %% [markdown]
# ### #Target Column

# %% [markdown]
# ### Scores

# %%
sns.distplot(df['Scores'])
plt.title('Distribution of Scores',size=20)
plt.show()

# %%
sns.boxplot(df['Scores'])
plt.title('Boxplot for Target Column')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### #New Feature Creation

# %% [markdown]
# ### Grade

# %% [markdown]
# - Score >= 75      ------> A Grade
# - 75 > Scores >= 60 -----> B Grade
# - 60 > Scores >= 35 -----> C Grade

# %%
def getgrade(mark):
    if mark>=75:
        return "A"
    elif mark>=60 and mark<75:
        return "B"
    elif mark>=35 and mark<60:
        return "C"
    else:
        return "D"

# %%
df["Grade"]=df["Scores"].apply(getgrade)

# %%
df.head()
# Out:
#    Hours  Scores Grade
# 0    2.5      21     D
# 1    5.1      47     C
# 2    3.2      27     D
# 3    8.5      75     A
# 4    3.5      30     D

# %%
df["Grade"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Grade'>

# %%
sns.countplot(x=df['Grade'],order=df['Grade'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Grade', ylabel='count'>

# %% [markdown]
# ## #Feature

# %% [markdown]
# ### Hours Study

# %%
df['Hours'].describe()
# Out:
# count    25.000000
# mean      5.012000
# std       2.525094
# min       1.100000
# 25%       2.700000
# 50%       4.800000
# 75%       7.400000
# max       9.200000
# Name: Hours, dtype: float64

# %%
sns.distplot(df['Hours'])
plt.show()

# %%
sns.boxplot(df['Hours'])
plt.title('Boxplot for Hour Column')
plt.ylabel('hours')
plt.show()

# %%
sns.regplot(x= df['Hours'], y= df['Scores'])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Feature Selection

# %%
x=df.iloc[:,:-2]
y=df['Scores']

# %% [markdown]
# ### Spliting dataset

# %%
 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %% [markdown]
# <p><font size = 6, color ="maroon"><strong>Model Building</strong></font></p>

# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>LinearRegression Model-- Baseline Model</strong></font></p>

# %%
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Prediction

# %%
ypred = linreg.predict(X_test)

# %% [markdown]
# ### Slope Value

# %%
linreg.coef_
# Out:
# array([9.65029083])

# %% [markdown]
# ### Intercept value

# %%
linreg.intercept_
# Out:
# 3.4050301755918966

# %%
plt.scatter(X_train,y_train,color="red")
plt.plot(X_train,linreg.predict(X_train), color="blue")
plt.show()

# %% [markdown]
# <p><font size = 4, color ="maroon"><strong>Regression Evaluation Metrics.</strong></font></p>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

mae = mean_absolute_error(y_test,ypred)
mse = mean_squared_error(y_test,ypred)

rmse = np.sqrt(mse)

r2 = r2_score(y_test,ypred)

print(f"MAE :- {mae}\nMSE:- {mse}\nRMSE:- {rmse}\nACCURACY:- {r2}")
# Out:
# MAE :- 4.564015037730867
# MSE:- 24.074686364260973
# RMSE:- 4.9065962096203695
# ACCURACY:- 0.9435488190277577

# %% [markdown]
# <p><font size = 4, color ="maroon"><strong>Residue Plot</strong></font></p>

# %%
residue =y_test-ypred
fig, axes = plt.subplots( 1,2, figsize=(10,5))
sns.distplot(residue,ax=axes[0])
sns.scatterplot(x=y_test,y= residue,ax=axes[1])
plt.axhline(y=0, color='r', linestyle='--')
axes[1].set_xlabel('Y test')
axes[1].set_ylabel('Residual error')
fig.subplots_adjust(wspace=0.5)

# %% [markdown]
# <p><font size = 4, color ="maroon"><strong>Checking Training and Testing Accuracy.</strong></font></p>

# %%
train=linreg.score(X_train,y_train)
test=linreg.score(X_test,y_test)
print(f'Train:-{train}')
print(f'Test:-{test}')
# Out:
# Train:-0.9543348637719865
# Test:-0.9435488190277577

# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>RandomForestRegressor.</strong></font></p>

# %%
from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(n_estimators = 100,
                              random_state = 1,
                              n_jobs = -1)
rfr.fit(X_train,y_train)
ypred=rfr.predict(X_test)

mae=mean_absolute_error(y_test,ypred,)
rmse=np.sqrt(mean_absolute_error(y_test,ypred,))
R2score=r2_score(y_test,ypred)

print(f'Mean Absolute Error:--{mae}')
print(f'Root Mean Square Error:--{rmse}')
print(f'R2 Score:--{R2score}')
print()
train=rfr.score(X_train,y_train)
test=rfr.score(X_test,y_test)
print(f'Train:-{train}')
print(f'Test:-{test}')
# Out:
# Mean Absolute Error:--4.868888888888888
# Root Mean Square Error:--2.2065558884580487
# R2 Score:--0.909342351783233
#
# Train:-0.9893710396704576
# Test:-0.909342351783233

# %% [markdown]
# <p><font size = 3, color ="blue"><strong>LinearRegression Model Performs Best With accuracy of 94%.</strong></font></p>

# %% [markdown]
# <p><font size = 5, color ="maroon"><strong>Model Testing On New Observation.</strong></font></p>

# %%
newob = 9.25
yp = linreg.predict([[newob]])[0]
print(f"If you Study of {newob} hrs/day, You will Get Score Around {yp}% ")
# Out:
# If you Study of 9.25 hrs/day, You will Get Score Around 92.67022037739969%

# %% [markdown]
# <p><font size = 4, color ="sky blue"><strong>
#     If you Study of 9.25 hrs/day, You will Get Score Around 92.67% .</strong></font></p>
